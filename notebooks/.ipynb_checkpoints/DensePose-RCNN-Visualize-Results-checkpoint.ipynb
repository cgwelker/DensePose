# %%
import numpy
import cv2
import matplotlib.pyplot as plt
import numpy as np

# im  = cv2.imread('../DensePoseData/demo_data/demo_im.jpg')
# IUV = cv2.imread('../DensePoseData/infer_out/demo_im_IUV.png')
# INDS = cv2.imread('../DensePoseData/infer_out/demo_im_INDS.png',  0)

# %%
IUV = cv2.imread('./000053_IUV.png')
INDS = cv2.imread('./000053_INDS.png')

print("IUV")
print(IUV.shape)

print('\nINDS')
print(INDS.shape)
# Out:
# IUV
# (480, 640, 3)
#
# INDS
# (480, 640, 3)

# %% [markdown]
# Let's visualize the I, U and V images.

# %%
fig = plt.figure(figsize=[15,15])
plt.imshow(   np.hstack((IUV[:,:,0]/24. ,IUV[:,:,1]/256. ,IUV[:,:,2]/256.))  )
plt.title('I, U and V images.')
plt.axis('off') ; plt.show()

# %% [markdown]
# fig = plt.figure(figsize=[15,15])
# plt.imshow(   np.hstack((IUV[:,:,0]/24. ,IUV[:,:,1]/256. ,IUV[:,:,2]/256.))  )
# plt.title('I, U and V images.')
# plt.axis('off') ; plt.show()

# %% [markdown]
# Let's visualize the isocontours of the UV fields.

# %%
fig = plt.figure(figsize=[12,12])
# plt.imshow( im[:,:,::-1] )
plt.contour( IUV[:,:,1]/256.,10, linewidths = 1 )
plt.contour( IUV[:,:,2]/256.,10, linewidths = 1 )
plt.axis('off') ; plt.show()

# %% [markdown]
# Let's visualize the human-body FG mask indices.

# %%
fig = plt.figure(figsize=[12,12])
# plt.imshow( im[:,:,::-1] )
plt.contour( INDS, linewidths = 4 )
plt.axis('off') ; plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-350906faf946> in <module>()
#       1 fig = plt.figure(figsize=[12,12])
#       2 # plt.imshow( im[:,:,::-1] )
# ----> 3 plt.contour( INDS, linewidths = 4 )
#       4 plt.axis('off') ; plt.show()
#
# C:\Anaconda3\envs\pycnn3\lib\site-packages\matplotlib\pyplot.py in contour(data, *args, **kwargs)
#    2510 @_autogen_docstring(Axes.contour)
#    2511 def contour(*args, data=None, **kwargs):
# -> 2512     __ret = gca().contour(*args, data=data, **kwargs)
#    2513     if __ret._A is not None: sci(__ret)
#    2514     return __ret
#
# C:\Anaconda3\envs\pycnn3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1783                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1784                         RuntimeWarning, stacklevel=2)
# -> 1785             return func(ax, *args, **kwargs)
#    1786
#    1787         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# C:\Anaconda3\envs\pycnn3\lib\site-packages\matplotlib\axes\_axes.py in contour(self, *args, **kwargs)
#    6207     def contour(self, *args, **kwargs):
#    6208         kwargs['filled'] = False
# -> 6209         contours = mcontour.QuadContourSet(self, *args, **kwargs)
#    6210         self.autoscale_view()
#    6211         return contours
#
# C:\Anaconda3\envs\pycnn3\lib\site-packages\matplotlib\contour.py in __init__(self, ax, levels, filled, linewidths, linestyles, alpha, origin, extent, cmap, colors, norm, vmin, vmax, extend, antialiased, *args, **kwargs)
#     885         self._transform = kwargs.pop('transform', None)
#     886
# --> 887         kwargs = self._process_args(*args, **kwargs)
#     888         self._process_levels()
#     889
#
# C:\Anaconda3\envs\pycnn3\lib\site-packages\matplotlib\contour.py in _process_args(self, *args, **kwargs)
#    1491                 self._corner_mask = mpl.rcParams['contour.corner_mask']
#    1492
# -> 1493             x, y, z = self._contour_args(args, kwargs)
#    1494
#    1495             _mask = ma.getmask(z)
#
# C:\Anaconda3\envs\pycnn3\lib\site-packages\matplotlib\contour.py in _contour_args(self, args, kwargs)
#    1546         if Nargs <= 2:
#    1547             z = ma.asarray(args[0], dtype=np.float64)
# -> 1548             x, y = self._initialize_x_y(z)
#    1549             args = args[1:]
#    1550         elif Nargs <= 4:
#
# C:\Anaconda3\envs\pycnn3\lib\site-packages\matplotlib\contour.py in _initialize_x_y(self, z)
#    1633         """
#    1634         if z.ndim != 2:
# -> 1635             raise TypeError("Input must be a 2D array.")
#    1636         elif z.shape[0] < 2 or z.shape[1] < 2:
#    1637             raise TypeError("Input z must be at least a 2x2 array.")
#
# TypeError: Input must be a 2D array.

# %%
fig = plt.figure(figsize=[12,12])
# plt.imshow( im[:,:,::-1] )
plt.contour( INDS, linewidths = 4 )
plt.axis('off') ; plt.show()
